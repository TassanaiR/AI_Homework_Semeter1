# %% [markdown]
# <a href="https://colab.research.google.com/github/TassanaiR/AI_Homework_Semeter1/blob/Week3/AI_Homework_Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Instructions***
# 1.create or find your own training and testing dataset
#
# 2.use google teachable machine to train the model
#
# 3.test your model using the test set and create confusion matrix
#
# 4.submit your work
#
#   4.1 link to your model
#
#   4.2 your dataset (both train and test)
#
#   4.3 explanation of your work (what are you training + how do you obtain dataset) + confusion matrix

# %% [markdown]
# #***Answers***
#
# 4.1 link to your model >> https://teachablemachine.withgoogle.com/models/zjaWTAy6q/
#
# 4.2 your dataset (both train and test) >> https://www.kaggle.com/datasets/borhanitrash/animal-image-classification-dataset
#
# 4.3 explanation of your work (what are you training + how do you obtain dataset) + confusion matrix
#
#
#
# I created a model to predict animal each types (Cats, Dogs, Snakes) by using the Teachable Machine and dowload the dataset from Kaggle. The image below is confusion matrix of my model.
#
#
# ![confusion matrix.png](data:image/png;base64,...)
